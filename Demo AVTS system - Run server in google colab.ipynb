# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Capstone 2 - AVTS/Project/TextSummarization
# Out:
# /content/drive/MyDrive/Capstone 2 - AVTS/Project/TextSummarization

# %%
# !pip install transformers
# !pip install pyvi
# !pip install spacy
# !pip -q install pyngrok
# !pip install fastapi
# !pip install uvicorn
# !pip install python-multipart
# !pip install aiofiles
# !pip install newspaper3k
# !pip install nest-asyncio
# Out:
# ...
#      |████████████████████████████████| 1.5MB 9.2MB/s
# ...
#      |████████████████████████████████| 890kB 22.4MB/s
# ...
#      |████████████████████████████████| 2.9MB 40.8MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=999905cdddb67ba9298c1e8ef53ba0753a9168ab0c474b8650d8c2a941c114ae
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...
#      |████████████████████████████████| 8.5MB 5.6MB/s
# ...
#      |████████████████████████████████| 747kB 54.5MB/s
# ...
#      |████████████████████████████████| 51kB 4.0MB/s
# ...
#      |████████████████████████████████| 9.2MB 8.2MB/s
# ...
#      |████████████████████████████████| 61kB 4.3MB/s
# ...
#      |████████████████████████████████| 51kB 3.8MB/s
# ...
#      |████████████████████████████████| 61kB 5.9MB/s
# ...

# %%
# !pip install ftfy
# !pip install bogo
# !pip install pycountry
# !pip install breadability
# !pip install pyvi
#!pip install scikit-learn --upgrade
import nltk
nltk.download('punkt')
# Out:
# ...
#      |████████████████████████████████| 71kB 5.7MB/s
# ...
#   Created wheel for ftfy: filename=ftfy-5.8-cp36-none-any.whl size=45613 sha256=dda5b648e0cebad11225fb79b92b1f15eed00fa917f238629ac80a8c51da8598
#   Stored in directory: /root/.cache/pip/wheels/ba/c0/ef/f28c4da5ac84a4e06ac256ca9182fc34fa57fefffdbc68425b
# Successfully built ftfy
# ...
#   Created wheel for bogo: filename=bogo-1.1-cp36-none-any.whl size=28138 sha256=5eeaa69e7ccc995b8f0f5ba33157e8c603145b79e77be1b72e58ab40ab38a48e
#   Stored in directory: /root/.cache/pip/wheels/5d/90/02/49165c6c062e760067fa27ced64563f228acd9ee2be501d4eb
# Successfully built bogo
# ...
#      |████████████████████████████████| 10.1MB 8.1MB/s
# ...
#   Created wheel for pycountry: filename=pycountry-20.7.3-py2.py3-none-any.whl size=10746863 sha256=0ae152da7937924eb698fc68e050d0076e6bb8de03142a2d355532488b8001fe
#   Stored in directory: /root/.cache/pip/wheels/33/4e/a6/be297e6b83567e537bed9df4a93f8590ec01c1acfbcd405348
# Successfully built pycountry
# ...

# %%
import formatSent as f

https://plo.vn/thoi-su/hieu-dung-viec-csgt-dan-thong-bao-vi-pham-len-kinh-o-to-957610.html

# %%
text = 'gía cả thị trừơng ngaỳ tăng cao'
f.clean_tone(text)
# Out:
# 'giá cả thị trường ngày tăng cao'

# %%
# !python server.py
# Out:
# 2020-12-24 09:16:57.735744: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Public URL: http://50b34da7f2af.ngrok.io
# INFO:     Started server process [743]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     171.255.175.187:0 - "GET / HTTP/1.1" 200 OK
# INFO:     171.255.175.187:0 - "GET /static/capstone2style.css HTTP/1.1" 200 OK
# INFO:     171.255.175.187:0 - "GET /static/main.js HTTP/1.1" 200 OK
# INFO:     171.255.175.187:0 - "GET /static/logo.png HTTP/1.1" 200 OK
# INFO:     171.255.175.187:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# Special tokens have been added in the vocabulary, make sure the associated word embedding are fine-tuned or trained.
# ...

# %%
from summarizer import Summarizer 
a = Summarizer()
line = '''Trong khi đó, Công ty Pfizer cho biết đang tìm hiểu xem các mẫu máu lấy từ những người được tiêm vắc-xin có khả năng "vô hiệu hóa biến thể mới" hiệu quả đến đâu. Ông Ugur Sahin, Giám đốc điều hành Công ty BioNTech (Đức) - đối tác phát triển vắc-xin Covid-19 của Pfizer, cũng tự tin khẳng định khả năng sản phẩm của họ có tác dụng chống lại biến thể mới là "tương đối cao", đặc biệt là khi các protein trên biến thể mới giống đến 99% so với chủng gốc. Cũng theo ông Sahin, nếu cần thiết, BioNTech có thể điều chỉnh vắc-xin chỉ trong 6 tuần để phù hợp với biến thể Covid-19 mới. Trong bối cảnh hàng chục nước trên thế giới ngăn chặn dòng người và hàng hóa từ Anh để phòng tránh biến thể mới, giới khoa học đang chạy đua để tìm hiểu nguồn gốc và quy mô của mối đe dọa này. Trung tâm Kiểm soát và Phòng ngừa dịch bệnh châu Âu (ECDC) khẳng định virus luôn thay đổi thông qua đột biến và SARS-CoV-2 cũng không ngoại lệ. Do đó, sự xuất hiện của biến thể mới đã được lường trước và bản thân nó không phải là một mối lo ngại. Trước biến thể này, nhiều biến thể khác cũng đã xuất hiện nhưng phần lớn là lành tính.'''
gg = a.run_embeddings(line, num_sentences=2)
gg
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embedding are fine-tuned or trained.
# array([[-0.01461767, -0.01444326, -0.05597923, ..., -0.14172743,
#         -0.04709966,  0.05490574],
#        [-0.18316782, -0.02496537, -0.00160482, ..., -0.08566773,
#          0.05813466, -0.03679007]], dtype=float32)

# %%
# Out:
# 2
